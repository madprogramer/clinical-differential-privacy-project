# %%
#!pip install smartnoise-sql
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 145.7/145.7 kB 3.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 23.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 9.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.9/19.9 MB 27.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.1/175.1 kB 17.2 MB/s eta 0:00:00
#   Installing build dependencies ... canceledERROR: Operation cancelled by user

# %%
# !pip install smartnoise-synth
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.7/83.7 kB 3.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 32.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 78.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.3/114.3 kB 11.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 887.5/887.5 MB 1.4 MB/s eta 0:00:00
# ...
#   Using cached opendp-0.6.2-py3-none-any.whl (19.9 MB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 145.1/145.1 kB 18.0 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached graphviz-0.17-py3-none-any.whl (18 kB)
# ...
#   Using cached antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 75.7 MB/s eta 0:00:00
# ...
#   Using cached PyYAML-5.4.1.tar.gz (175 kB)
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# import snsql
# from snsql import Privacy
# import pandas as pd
# privacy = Privacy(epsilon=1.0, delta=0.01)

# csv_path = 'PUMS.csv'
# meta_path = 'PUMS.yaml'

# pums = pd.read_csv(csv_path)
# reader = snsql.from_df(pums, privacy=privacy, metadata=meta_path)

# result = reader.execute('SELECT sex, AVG(age) AS age FROM PUMS.PUMS GROUP BY sex')

# %%
#!cd sql
#!pip install -r tests/requirements.txt
#!python tests/check_databases.py
#!pip install pandas -U
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
#import pandas as pd
#pd.util.testing.makeDataFrame()
#!ls drive/MyDrive/DATA
# Out:
# PUMS.csv

# %%
import pandas as pd
from snsynth import Synthesizer

pums_csv_path = 'drive/MyDrive/DATA/PUMS.csv'
pums = pd.read_csv(pums_csv_path)
#print(pums.head())

#synth = Synthesizer.create("dpctgan", epsilon=3.0, verbose=True)
synth = Synthesizer.create("patectgan", epsilon=3.0, verbose=True)

synth.fit(pums, preprocessor_eps=1.0)
pums_synth = synth.sample(1000)
# Out:
#    age  sex  educ  race   income  married  pid
# 0   59    1     9     1      0.0        1    1
# 1   31    0     1     3  17000.0        0    2
# 2   36    1    11     1      0.0        1    3
# 3   54    1    11     1   9100.0        1    4
# 4   39    0     5     3  37000.0        0    5
# Spent 1.0 epsilon on preprocessor, leaving 2.0 for training
# using loss cross_entropy and regularization None
# eps: 0.103616 	 G: 2.890772 	 D: 0.705899
# eps: 0.460253 	 G: 2.928176 	 D: 0.698974
# eps: 0.653801 	 G: 2.895762 	 D: 0.706427
# eps: 0.803524 	 G: 2.825479 	 D: 0.724868
# eps: 0.930506 	 G: 2.903598 	 D: 0.745571
# eps: 1.043082 	 G: 2.868745 	 D: 0.724067
# eps: 1.145349 	 G: 2.869002 	 D: 0.762036
# eps: 1.239508 	 G: 2.922393 	 D: 0.763398
# eps: 1.327602 	 G: 2.809886 	 D: 0.798969
# eps: 1.410776 	 G: 2.945826 	 D: 0.782269
# eps: 1.490117 	 G: 2.895889 	 D: 0.763127
# eps: 1.565117 	 G: 2.894054 	 D: 0.783171
# eps: 1.637049 	 G: 2.815840 	 D: 0.787972
# ...

# %%
print(pums.head())
pums_synth.head()
# Out:
#    age  sex  educ  race   income  married  pid
# 0   59    1     9     1      0.0        1    1
# 1   31    0     1     3  17000.0        0    2
# 2   36    1    11     1      0.0        1    3
# 3   54    1    11     1   9100.0        1    4
# 4   39    0     5     3  37000.0        0    5
#    age  sex  educ  race        income  married  pid
# 0   82    0    16     1  17740.972656        0    1
# 1   30    0    13     4  31207.843750        1    2
# 2   20    1     9     6  27149.441406        0    3
# 3   31    0     9     3  17705.152344        1    4
# 4   29    1    11     4   7809.339844        0    5

# %%
from snsynth import Synthesizer
import pandas as pd

pums_csv_path = 'drive/MyDrive/DATA/PUMS.csv'
pums = pums.drop(['income', 'age'], axis=1)

synth = Synthesizer.create('mwem', epsilon=1.0)
sample = synth.fit_sample(pums)
print(sample)

sample_conditional = synth.sample_conditional(100, "educ < 10")
print(sample_conditional)

pums = pd.read_csv(pums_csv_path, index_col='pid') # in datasets/
# Out:
#      sex  educ  race  married
# 0      0    14     1        1
# 1      1     6     1        0
# 2      1     6     1        0
# 3      0     9     4        1
# 4      0    11     2        0
# ..   ...   ...   ...      ...
# 995    1    14     1        0
# 996    0     8     1        0
# 997    1     9     3        1
# 998    1     6     3        0
# 999    0     9     4        1
#
# [1000 rows x 4 columns]
#     sex  educ  race  married
# 0     1     6     3        0
# 1     1     6     3        0
# 2     1     9     3        1
# 3     1     9     2        1
# 4     1     6     1        0
# ..  ...   ...   ...      ...
# 95    1     9     3        1
# 96    0     8     1        1
# 97    0     7     5        0
# 98    0     7     3        0
# 99    0     9     4        1
#
# [100 rows x 4 columns]

# %%
pums_synth.head()
# Out:
#    sex  educ  race  married
# 0    1    12     6        0
# 1    1    12     4        1
# 2    1     4     2        0
# 3    1    15     1        0
# 4    0    11     1        0
