# %% [markdown]
# ## 1. Installation and Data Loading

# %%
# !pip install smartnoise-synth
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting smartnoise-synth
#   Downloading smartnoise_synth-1.0.0-py3-none-any.whl (83 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.7/83.7 kB 8.5 MB/s eta 0:00:00
# Collecting Faker<16.0.0,>=15.0.0 (from smartnoise-synth)
#   Downloading Faker-15.3.4-py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 63.2 MB/s eta 0:00:00
# Collecting opacus<0.15.0,>=0.14.0 (from smartnoise-synth)
#   Downloading opacus-0.14.0-py3-none-any.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.3/114.3 kB 12.3 MB/s eta 0:00:00
# Collecting opendp<0.7.0,>=0.6.0 (from smartnoise-synth)
#   Downloading opendp-0.6.2-py3-none-any.whl (19.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.9/19.9 MB 49.6 MB/s eta 0:00:00
# Collecting pac-synth<0.0.9,>=0.0.8 (from smartnoise-synth)
#   Downloading pac_synth-0.0.8-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 47.0 MB/s eta 0:00:00
# Collecting smartnoise-sql<2.0.0,>=1.0.0 (from smartnoise-synth)
#   Downloading smartnoise_sql-1.0.0-py3-none-any.whl (145 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 145.7/145.7 kB 15.8 MB/s eta 0:00:00
# Collecting torch<2.0.0 (from smartnoise-synth)
#   Downloading torch-1.13.1-cp310-cp310-manylinux1_x86_64.whl (887.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 887.5/887.5 MB 1.6 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.4 in /usr/local/lib/python3.10/dist-packages (from Faker<16.0.0,>=15.0.0->smartnoise-synth) (2.8.2)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.10/dist-packages (from opacus<0.15.0,>=0.14.0->smartnoise-synth) (1.22.4)
# Requirement already satisfied: scipy>=1.2 in /usr/local/lib/python3.10/dist-packages (from opacus<0.15.0,>=0.14.0->smartnoise-synth) (1.10.1)
# Collecting PyYAML<6.0.0,>=5.4.1 (from smartnoise-sql<2.0.0,>=1.0.0->smartnoise-synth)
#   Downloading PyYAML-5.4.1.tar.gz (175 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.1/175.1 kB 18.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting antlr4-python3-runtime==4.9.3 (from smartnoise-sql<2.0.0,>=1.0.0->smartnoise-synth)
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 15.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting graphviz<0.18,>=0.17 (from smartnoise-sql<2.0.0,>=1.0.0->smartnoise-synth)
#   Downloading graphviz-0.17-py3-none-any.whl (18 kB)
# Collecting pandas<3.0.0,>=2.0.1 (from smartnoise-sql<2.0.0,>=1.0.0->smartnoise-synth)
#   Downloading pandas-2.0.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 90.3 MB/s eta 0:00:00
# Requirement already satisfied: sqlalchemy<3.0.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from smartnoise-sql<2.0.0,>=1.0.0->smartnoise-synth) (2.0.10)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch<2.0.0->smartnoise-synth) (4.5.0)
# Collecting nvidia-cuda-runtime-cu11==11.7.99 (from torch<2.0.0->smartnoise-synth)
#   Downloading nvidia_cuda_runtime_cu11-11.7.99-py3-none-manylinux1_x86_64.whl (849 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.3/849.3 kB 64.8 MB/s eta 0:00:00
# Collecting nvidia-cudnn-cu11==8.5.0.96 (from torch<2.0.0->smartnoise-synth)
#   Downloading nvidia_cudnn_cu11-8.5.0.96-2-py3-none-manylinux1_x86_64.whl (557.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 557.1/557.1 MB 1.6 MB/s eta 0:00:00
# Collecting nvidia-cublas-cu11==11.10.3.66 (from torch<2.0.0->smartnoise-synth)
#   Downloading nvidia_cublas_cu11-11.10.3.66-py3-none-manylinux1_x86_64.whl (317.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.1/317.1 MB 3.6 MB/s eta 0:00:00
# Collecting nvidia-cuda-nvrtc-cu11==11.7.99 (from torch<2.0.0->smartnoise-synth)
#   Downloading nvidia_cuda_nvrtc_cu11-11.7.99-2-py3-none-manylinux1_x86_64.whl (21.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.0/21.0 MB 60.0 MB/s eta 0:00:00
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch<2.0.0->smartnoise-synth) (67.7.2)
# Requirement already satisfied: wheel in /usr/local/lib/python3.10/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch<2.0.0->smartnoise-synth) (0.40.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0.0,>=2.0.1->smartnoise-sql<2.0.0,>=1.0.0->smartnoise-synth) (2022.7.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0.0,>=2.0.1->smartnoise-sql<2.0.0,>=1.0.0->smartnoise-synth) (2023.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.4->Faker<16.0.0,>=15.0.0->smartnoise-synth) (1.16.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy<3.0.0,>=2.0.0->smartnoise-sql<2.0.0,>=1.0.0->smartnoise-synth) (2.0.2)
# Building wheels for collected packages: antlr4-python3-runtime, PyYAML
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144554 sha256=cd050a5275af2ce23a86e23b5509ec36bb017221f6595fcbe994b4252a70289f
#   Stored in directory: /root/.cache/pip/wheels/12/93/dd/1f6a127edc45659556564c5730f6d4e300888f4bca2d4c5a88
#   Building wheel for PyYAML (pyproject.toml) ... done
#   Created wheel for PyYAML: filename=PyYAML-5.4.1-cp310-cp310-linux_x86_64.whl size=45658 sha256=1522fa0045a4c7e38c09e43e828b36e212c0a887452e03127e6143eab9e8bb27
#   Stored in directory: /root/.cache/pip/wheels/c7/0d/22/696ee92245ad710f506eee79bb05c740d8abccd3ecdb778683
# Successfully built antlr4-python3-runtime PyYAML
# Installing collected packages: antlr4-python3-runtime, PyYAML, pac-synth, opendp, nvidia-cuda-runtime-cu11, nvidia-cuda-nvrtc-cu11, nvidia-cublas-cu11, graphviz, pandas, nvidia-cudnn-cu11, Faker, torch, smartnoise-sql, opacus, smartnoise-synth
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 6.0
#     Uninstalling PyYAML-6.0:
#       Successfully uninstalled PyYAML-6.0
#   Attempting uninstall: graphviz
#     Found existing installation: graphviz 0.20.1
#     Uninstalling graphviz-0.20.1:
#       Successfully uninstalled graphviz-0.20.1
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.5.3
#     Uninstalling pandas-1.5.3:
#       Successfully uninstalled pandas-1.5.3
#   Attempting uninstall: torch
#     Found existing installation: torch 2.0.1+cu118
#     Uninstalling torch-2.0.1+cu118:
#       Successfully uninstalled torch-2.0.1+cu118
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==1.5.3, but you have pandas 2.0.1 which is incompatible.
# torchaudio 2.0.2+cu118 requires torch==2.0.1, but you have torch 1.13.1 which is incompatible.
# torchdata 0.6.1 requires torch==2.0.1, but you have torch 1.13.1 which is incompatible.
# torchtext 0.15.2 requires torch==2.0.1, but you have torch 1.13.1 which is incompatible.
# torchvision 0.15.2+cu118 requires torch==2.0.1, but you have torch 1.13.1 which is incompatible.
# Successfully installed Faker-15.3.4 PyYAML-5.4.1 antlr4-python3-runtime-4.9.3 graphviz-0.17 nvidia-cublas-cu11-11.10.3.66 nvidia-cuda-nvrtc-cu11-11.7.99 nvidia-cuda-runtime-cu11-11.7.99 nvidia-cudnn-cu11-8.5.0.96 opacus-0.14.0 opendp-0.6.2 pac-synth-0.0.8 pandas-2.0.1 smartnoise-sql-1.0.0 smartnoise-synth-1.0.0 torch-1.13.1

# %%
# !pip install git+https://github.com/ryan112358/private-pgm.git
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting git+https://github.com/ryan112358/private-pgm.git
#   Cloning https://github.com/ryan112358/private-pgm.git to /tmp/pip-req-build-zmw063pe
#   Running command git clone --filter=blob:none --quiet https://github.com/ryan112358/private-pgm.git /tmp/pip-req-build-zmw063pe
#   Resolved https://github.com/ryan112358/private-pgm.git to commit 5b9126295c110b741e5426ddbff419ea1e60e788
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from private-pgm==0.0.1) (1.22.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from private-pgm==0.0.1) (1.10.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from private-pgm==0.0.1) (2.0.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from private-pgm==0.0.1) (3.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from private-pgm==0.0.1) (3.7.1)
# Collecting nose (from private-pgm==0.0.1)
#   Downloading nose-1.3.7-py3-none-any.whl (154 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.7/154.7 kB 9.7 MB/s eta 0:00:00
# Collecting disjoint-set (from private-pgm==0.0.1)
#   Downloading disjoint_set-0.7.3-py3-none-any.whl (5.2 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->private-pgm==0.0.1) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->private-pgm==0.0.1) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->private-pgm==0.0.1) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->private-pgm==0.0.1) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->private-pgm==0.0.1) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->private-pgm==0.0.1) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->private-pgm==0.0.1) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->private-pgm==0.0.1) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->private-pgm==0.0.1) (2022.7.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->private-pgm==0.0.1) (2023.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->private-pgm==0.0.1) (1.16.0)
# Building wheels for collected packages: private-pgm
#   Building wheel for private-pgm (setup.py) ... done
#   Created wheel for private-pgm: filename=private_pgm-0.0.1-py3-none-any.whl size=41240 sha256=3808f2cdce25b36f78e3c2b424143afa56c4c81a770a64b14327e4fb3177408c
#   Stored in directory: /tmp/pip-ephem-wheel-cache-2fv73zvd/wheels/0f/3e/df/50e38e22bfd2627d967bd57bd930405599142e9b39870cd9fe
# Successfully built private-pgm
# Installing collected packages: nose, disjoint-set, private-pgm
# Successfully installed disjoint-set-0.7.3 nose-1.3.7 private-pgm-0.0.1

# %%
from snsynth import Synthesizer
import pandas as pd

#data_csv_path = 'drive/MyDrive/DATA/MTX_NAs_Dropped.csv'
data_csv_path = 'drive/MyDrive/DATA/MTX_NAs_Dropped_v2.csv'
das_score_cols = ['das28_remission_m0','das28_remission_m3','das28_remission_m6','das28_remission_m12']

dat = pd.read_csv(data_csv_path,sep=' ') # in datasets/
# Check if dat lodade correctly
#dat.head()

# %%
from snsynth.transform import TableTransformer, LabelTransformer, MinMaxTransformer, DropTransformer, BinTransformer

# V1
tt = TableTransformer([
    LabelTransformer(), # sex
    #MinMaxTransformer(lower=18, upper=100), # age
    #DropTransformer(), # IGNORING AGE
    BinTransformer(bins=10, lower=18, upper=100), # age
    LabelTransformer(), # das28_remission_m0
    LabelTransformer(), # das28_remission_m3
    LabelTransformer(), # das28_remission_m6
    LabelTransformer() # das28_remission_m12
])

tt_v2 =  TableTransformer([
    LabelTransformer(), # sex
    BinTransformer(bins=10, lower=18, upper=100), # age
    LabelTransformer(), # crp baseline
    BinTransformer(bins=4, lower=0, upper=100.1), # patient global assessment at baseline
    LabelTransformer(), # das28_remission_m0
    LabelTransformer(), # das28_remission_m3
    LabelTransformer(), # das28_remission_m6
    LabelTransformer() # das28_remission_m12
])


#dat_encoded = tt.fit_transform(dat)
#dat_encoded[0:10]

# tt_neural = TableTransformer([
#     LabelTransformer(), # sex
#     MinMaxTransformer(lower=18, upper=100), # age
#     LabelTransformer(), # das28_remission_m0
#     LabelTransformer(), # das28_remission_m3
#     LabelTransformer(), # das28_remission_m6
#     LabelTransformer() # das28_remission_m12
# ])

dat_encoded = tt_v2.fit_transform(dat)
dat_encoded[0:10]
# Out:
# [(1, 3, 1, 3, 0, 1, 0, 0),
#  (0, 2, 1, 2, 0, 0, 0, 0),
#  (0, 1, 0, 3, 0, 0, 0, 0),
#  (0, 4, 3, 2, 0, 0, 0, 0),
#  (0, 3, 1, 1, 0, 1, 1, 1),
#  (0, 2, 3, 3, 0, 0, 0, 0),
#  (0, 3, 1, 2, 0, 1, 1, 1),
#  (0, 3, 1, 2, 0, 0, 0, 0),
#  (0, 3, 1, 2, 0, 0, 0, 0),
#  (0, 6, 3, 3, 0, 0, 0, 0)]

# %% [markdown]
# ## 2. Set up Synthesizer

# %%
# synth = Synthesizer.create('dpctgan', epsilon=10.0, batch_size=400,
#                            embedding_dim=8, generator_dim=(16, 16), discriminator_dim=(16, 16),
#                            generator_lr=0.0005, generator_decay=1e-06,
#                            discriminator_lr=0.0005, discriminator_decay=1e-06,
#                            discriminator_steps=1, pac=1, cuda=True,
#                            disabled_dp=False, delta=None, sigma=5,
#                            max_per_sample_grad_norm=1.0, loss='cross_entropy',


#                            epochs=300,
#                            verbose=True,

#                            )

# PAC SYNTH IS BUGGED, OMITTING
# synth = Synthesizer.create('pacsynth', epsilon=0.1, delta=None, empty_value='',
#                            reporting_length=2, percentile_percentage=99, percentile_epsilon_proportion=0.01,
#                            number_of_records_epsilon_proportion=0.005, use_synthetic_counts=False,
#                            weight_selection_percentile=95, aggregate_counts_scale_factor=None, verbose=True)


# sample_dat = synth.fit_sample(
#     dat, transformer=tt_v2,
#     )
synth = Synthesizer.create(
            'mst', epsilon=0.1, delta=1e-09, verbose=False
            )

#synth.fit(dat, transformer=tt_v2)
sample_dat = synth.fit_sample(dat, transformer=tt_v2)
#N=len(dat)
#sample_dat = synth.sample_conditional(N, condition="pga_m0>-1000")
#sample_dat = synth.sample_conditional(N, "pga_m0 >= 0 AND pga_m0 <= 100")

# sample_dat = synth.fit_sample(
#    dat, transformer=tt_neural,
#    categorical_columns=['sex','das28_remission_m0','das28_remission_m3','das28_remission_m6','das28_remission_m12'],
#    ordinal_columns=[], continuous_columns=['age']
#    )
# sample_dat = synth.fit_sample(dat, preprocessor_eps=1.0)
#print(sample_dat)

# %%
#from collections import Counter
#Counter(sample_dat['pga_m0'])

# %%
#x = dat
#plt.plot()

x = (0,3,6,12)

dat_sub = dat[['das28_remission_m0','das28_remission_m3','das28_remission_m6','das28_remission_m12']]
y1 = list(dat_sub.mean())

sample_dat_sub = sample_dat[['das28_remission_m0','das28_remission_m3','das28_remission_m6','das28_remission_m12']]
y2 = list(sample_dat_sub.mean())

#sample_dat_sub =
#y1 = ()
#print(sample_dat)

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
ax = plt.gca()
plt.plot(x,y1,'v',linestyle='dashed',label='Original Data')
#plt.plot(x,y2,label='Synthetic Data')
#plt.legend()
plt.title("Rate of Remission over Time")
plt.ylabel("Percentage of Patients in Remission")
ax.set_ylim(bottom=0, top=0.2)
plt.xlabel("Month")
# Out:
# Text(0.5, 0, 'Month')

# %%
np.around(y1,4)*100
# Out:
# array([ 5.36, 19.16, 16.52, 13.44])

# %%
ax = plt.gca()
plt.plot(x,y1,'v',linestyle='dashed',label='Original Data')
plt.plot(x,y2,'*',linestyle='dashed',label='Synthetic Data')
plt.legend()
ax.set_ylim(bottom=0, top=0.4)
plt.title("Rate of Remission over Time")
plt.ylabel("Percentage of Patients in Remission")
plt.xlabel("Month")
# Out:
# Text(0.5, 0, 'Month')

# %%
np.around(y2,4)*100
# Out:
# array([ 0.  , 47.28,  5.86, 18.05])

# %% [markdown]
# ## 3. Generate Samples

# %%
#eps = (0.05, 0.1, 0.2, 0.5, 1.0, 1.25, 1.5, 2.0, 2.5, 3.0, 3.5, 4.0, 5.0, 10.0)
#eps = (0.05, 0.1)
#eps = (0.2, 0.5)
#eps = (1.0, 1.25)
#eps = (1.5, 2.0)
#eps = (2.5, 3.0)
#eps = (3.5, 4.0)
#eps = (5.0, 10.0)

#eps = (1.0, 2.0)
#eps = (5.0,10.0)

#eps = (0.1, 10.0)

neps = len(eps)
K = 20
synthesizer_count = 3
trials = []

from tqdm.notebook import tqdm


for i in tqdm(range(neps), position=0, desc="i", leave=False, colour='green', ncols=80):
  trials.append([])
  synthesizers = [
        Synthesizer.create(
            'mwem', epsilon=eps[i], split_factor=10,
            q_count=None, iterations=None, splits=[],
            marginal_width=None, add_ranges=False, measure_only=False, max_retries_exp_mechanism=10, mult_weights_iterations=20,
            verbose=False
            ),
        Synthesizer.create(
            'mst', epsilon=eps[i], delta=1e-09, verbose=False
            ),
        Synthesizer.create(
            'aim', epsilon=eps[i], delta=1e-09,
            max_model_size=80, degree=2, num_marginals=None, max_cells=10000, rounds=None,
            verbose=False
            ),

        # Synthesizer.create('dpctgan', epsilon=eps[i], batch_size=400,
        #                    embedding_dim=8, generator_dim=(16, 16), discriminator_dim=(16, 16),
        #                    generator_lr=0.0005, generator_decay=1e-06,
        #                    discriminator_lr=0.0005, discriminator_decay=1e-06,
        #                    discriminator_steps=1, pac=1, cuda=True,
        #                    disabled_dp=False, delta=None, sigma=5,
        #                    max_per_sample_grad_norm=1.0, loss='cross_entropy',


        #                    epochs=300,
        #                    verbose=True,

        #                    )
  ]
  for j in tqdm(range(synthesizer_count), position=1, desc="j", leave=False, colour='green', ncols=80):
    trials[-1].append([])
    for k in tqdm(range(K), position=2, desc="k", leave=False, colour='green', ncols=80):
      synth = synthesizers[j]
      # DO NOT USE TRANSFORMER FOR GANS!
      # if j >= 2:
      #   trial = synth.fit_sample(dat, preprocessor_eps=1.0)
      # else:
      #   trial = synth.fit_sample(dat, transformer=tt, preprocessor_eps=1.0)
      trial = synth.fit_sample(dat, transformer=tt_v2)
      trials[-1][-1].append(trial)
      #print(trials)
# Out:
# i:   0%|                                                  | 0/2 [00:00<?, ?it/s]
# j:   0%|                                                  | 0/3 [00:00<?, ?it/s]
# k:   0%|                                                 | 0/20 [00:00<?, ?it/s]
# k:   0%|                                                 | 0/20 [00:00<?, ?it/s]
# k:   0%|                                                 | 0/20 [00:00<?, ?it/s]
# 8
# Initial Sigma 28.82550958049311
# 8
# Initial Sigma 28.82550958049311
# 8
# Initial Sigma 28.82550958049311
# 8
# Initial Sigma 28.82550958049311
# 8
# Initial Sigma 28.82550958049311
# 8
# Initial Sigma 28.82550958049311
# 8
# Initial Sigma 28.82550958049311
# 8
# Initial Sigma 28.82550958049311
# 8
# Initial Sigma 28.82550958049311
# 8
# Initial Sigma 28.82550958049311
# 8
# Initial Sigma 28.82550958049311
# 8
# Initial Sigma 28.82550958049311
# 8
# Initial Sigma 28.82550958049311
# 8
# Initial Sigma 28.82550958049311
# 8
# Initial Sigma 28.82550958049311
# 8
# Initial Sigma 28.82550958049311
# 8
# Initial Sigma 28.82550958049311
# 8
# Initial Sigma 28.82550958049311
# 8
# Initial Sigma 28.82550958049311
# 8
# Initial Sigma 28.82550958049311
# j:   0%|                                                  | 0/3 [00:00<?, ?it/s]
# k:   0%|                                                 | 0/20 [00:00<?, ?it/s]
# k:   0%|                                                 | 0/20 [00:00<?, ?it/s]
# k:   0%|                                                 | 0/20 [00:00<?, ?it/s]
# 8
# Initial Sigma 24.28436313399808
# 8
# Initial Sigma 24.28436313399808
# 8
# Initial Sigma 24.28436313399808
# 8
# Initial Sigma 24.28436313399808
# 8
# Initial Sigma 24.28436313399808
# 8
# Initial Sigma 24.28436313399808
# 8
# Initial Sigma 24.28436313399808
# 8
# Initial Sigma 24.28436313399808
# 8
# Initial Sigma 24.28436313399808
# 8
# Initial Sigma 24.28436313399808
# 8
# Initial Sigma 24.28436313399808
# 8
# Initial Sigma 24.28436313399808
# 8
# Initial Sigma 24.28436313399808
# 8
# Initial Sigma 24.28436313399808
# 8
# Initial Sigma 24.28436313399808
# 8
# Initial Sigma 24.28436313399808
# 8
# Initial Sigma 24.28436313399808
# 8
# Initial Sigma 24.28436313399808
# 8
# Initial Sigma 24.28436313399808
# 8
# Initial Sigma 24.28436313399808

# %% [markdown]
# ## Optional.
#
# Save Snapshot of Data for Visualization Adjustments

# %%
import pickle, datetime

with open(f'drive/MyDrive/DATA/{datetime.datetime.now()}-mtx.pkl', 'wb') as outp:
    pickle.dump(trials, outp, pickle.HIGHEST_PROTOCOL)
