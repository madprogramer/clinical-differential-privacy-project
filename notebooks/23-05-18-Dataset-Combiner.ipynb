# %%
#eps = (0.05, 0.1) /content/drive/MyDrive/DATA/2023-05-17 10:08:20.979556-mtx.pkl [needs to be re-run]  2023-05-17 23:12:06.318414-mtx.pkl
#eps = (0.2, 0.5)  /content/drive/MyDrive/DATA/2023-05-17 14:03:09.947639-mtx.pkl
#eps = (1.0, 1.25) /content/drive/MyDrive/DATA/2023-05-17 17:11:07.581320-mtx.pkl
#eps = (1.5, 2.0)  /content/drive/MyDrive/DATA/2023-05-17 18:22:28.844890-mtx.pkl
#eps = (2.5, 3.0)  /content/drive/MyDrive/DATA/2023-05-21 16:31:56.371426-mtx.pkl
#eps = (3.5, 4.0)  /content/drive/MyDrive/DATA/2023-05-17 22:17:52.237134-mtx.pkl
#eps = (5.0, 10.0) /content/drive/MyDrive/DATA/2023-05-21 18:56:39.877061-mtx.pkl

# %%
import pickle
with open(f'drive/MyDrive/DATA/2023-05-17 10:08:20.979556-mtx.pkl', 'rb') as inp:
    trials  = pickle.load(inp)

# Special Fix
trials[0][2][7].loc[:,'das28_remission_m3']=0

with open(f'/content/drive/MyDrive/DATA/2023-05-17 14:03:09.947639-mtx.pkl', 'rb') as inp:
    trials += pickle.load(inp)

with open(f'/content/drive/MyDrive/DATA/2023-05-17 17:11:07.581320-mtx.pkl', 'rb') as inp:
    trials += pickle.load(inp)

with open(f'/content/drive/MyDrive/DATA/2023-05-17 18:22:28.844890-mtx.pkl', 'rb') as inp:
    trials += pickle.load(inp)

with open(f'/content/drive/MyDrive/DATA/2023-05-21 16:31:56.371426-mtx.pkl', 'rb') as inp:
    trials += pickle.load(inp)

with open(f'/content/drive/MyDrive/DATA/2023-05-17 22:17:52.237134-mtx.pkl', 'rb') as inp:
    trials += pickle.load(inp)

with open(f'/content/drive/MyDrive/DATA/2023-05-21 18:56:39.877061-mtx.pkl', 'rb') as inp:
    trials += pickle.load(inp)
# Out:
# <ipython-input-2-3df8c36b5ffa>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   trials[0][2][7].loc[:,'das28_remission_m3']=0

# %%
with open(f'/content/drive/MyDrive/DATA/2023-05-17 23:12:06.318414-mtx.pkl', 'rb') as inp:
    t = pickle.load(inp)

# %%
#print(len(t[]))
trials[0][2][7] = t[0][0][0]
#print(len(trials[0][2][8]))
#print(len(t[0][0]))

# %%
#len(trials)
import datetime

with open(f'drive/MyDrive/DATA/COMBINED-{datetime.datetime.now()}-Combined.pkl', 'wb') as outp:
    pickle.dump(trials, outp, pickle.HIGHEST_PROTOCOL)

# %%
#eps = [0.05, 0.1, 0.2, 0.5, 1.0, 1.25, 1.5, 2.0, 2.5, 3.0, 3.5, 4.0, 5.0, 10.0]
#eps = [0.05, 0.1, 0.2, 0.5, 1.0, 1.25, 1.5, 2.0, 3.5, 4.0]
